# %%
#Import requests library
import requests

crypto= requests.get('https://apiary.io')
print("crypto:", crypto.status_code)

food= requests.get("https://world.openfoodfacts.org")
print("food:", food.status_code)


disney= requests.get("https://disneyapi.dev")
print("disney:", disney.status_code)
# Out:
# crypto: 200
# food: 200
# disney: 200

# %%
import json

response1 = requests.get('https://api.n.exchange/en/api/v1/pair/')
response1.raise_for_status()   
result1= response.json()

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

data1 = pd.DataFrame(result1)
data1.head(10)
# Out:
#          name     base quote     fee_ask     fee_bid  disabled  test_mode  \
# 0      BDGBTC      BDG   BTC  0.02800000  0.02800000      True       True
# 1  LINKSOLBTC  LINKSOL   BTC  0.02800000  0.02800000      True       True
# 2      KCSBTC      KCS   BTC  0.02800000  0.02800000      True       True
# 3      VRABTC      VRA   BTC  0.02800000  0.02800000      True       True
# 4      RAYBTC      RAY   BTC  0.02800000  0.02800000      True       True
# 5      NEOBTC      NEO   BTC  0.02800000  0.02800000      True       True
# 6     COSSBTC     COSS   BTC  0.02800000  0.02800000      True       True
# 7      COBBTC      COB   BTC  0.02800000  0.02800000      True       True
# 8     USDTBTC     USDT   BTC  0.02800000  0.02800000      True       True
# 9      XEMBTC      XEM   BTC  0.02800000  0.02800000      True       True
#
#    orderbook_enabled  reverse_orderbook_enabled
# 0              False                      False
# 1              False                      False
# ...

# %%
response2 = requests.get('https://world.openfoodfacts.org/api/v0/product/737628064502.json')
response2.raise_for_status()   
result2= response2.json()

# %%
data2 = pd.DataFrame(result2)
data2.head(10)
# Out:
#                                        code  \
# _id                           0737628064502
# _keywords                     0737628064502
# added_countries_tags          0737628064502
# additives_debug_tags          0737628064502
# additives_n                   0737628064502
# additives_old_n               0737628064502
# additives_old_tags            0737628064502
# additives_original_tags       0737628064502
# additives_prev_original_tags  0737628064502
# additives_tags                0737628064502
#
#                                                                         product  \
# _id                                                               0737628064502
# _keywords                     [include, asia, gluten-free, peanut, potatoe, ...
# added_countries_tags                                                         []
# additives_debug_tags                                                         []
# ...

# %%
### to avoid a long page #####
# response3 = requests.get('https://api.disneyapi.dev/characters')
# response3.raise_for_status()    
# result3= response3.json()
# result3

# %%
import pandas as pd


data3 = pd.DataFrame(result3)
data3.head(10)
# Out:
#                                                 data  count  totalPages  \
# 0  {'films': [], 'shortFilms': [], 'tvShows': [],...     50         149
# 1  {'films': [], 'shortFilms': [], 'tvShows': ['G...     50         149
# 2  {'films': [], 'shortFilms': [], 'tvShows': ['L...     50         149
# 3  {'films': [], 'shortFilms': [], 'tvShows': [],...     50         149
# 4  {'films': [], 'shortFilms': [], 'tvShows': ['P...     50         149
# 5  {'films': [], 'shortFilms': [], 'tvShows': [],...     50         149
# 6  {'films': ['The Computer Wore Tennis Shoes', '...     50         149
# 7  {'films': [], 'shortFilms': [], 'tvShows': ['P...     50         149
# 8  {'films': ['Cheetah'], 'shortFilms': [], 'tvSh...     50         149
# 9  {'films': [], 'shortFilms': [], 'tvShows': ['T...     50         149
#
#                                       nextPage
# 0  https://api.disneyapi.dev/characters?page=2
# 1  https://api.disneyapi.dev/characters?page=2
# ...

# %%
dict(data3['data'])
pd.DataFrame(dict(data3['data']))
pd.DataFrame(dict(data3['data'])).transpose()
# Out:
#                                                 films shortFilms  \
# 0                                                  []         []
# 1                                                  []         []
# 2                                                  []         []
# 3                                                  []         []
# 4                                                  []         []
# 5                                                  []         []
# 6   [The Computer Wore Tennis Shoes, Now You See H...         []
# 7                                                  []         []
# 8                                           [Cheetah]         []
# 9                                                  []         []
# 10   [The Fox and the Hound, The Fox and the Hound 2]         []
# 11                                                 []         []
# ..                                                ...        ...
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
nested_columns = ['data']

flat = flatten(data3, nested_columns)
flat
# Out:
#     count  totalPages                                     nextPage  \
# 0      50         149  https://api.disneyapi.dev/characters?page=2
# 1      50         149  https://api.disneyapi.dev/characters?page=2
# 2      50         149  https://api.disneyapi.dev/characters?page=2
# 3      50         149  https://api.disneyapi.dev/characters?page=2
# 4      50         149  https://api.disneyapi.dev/characters?page=2
# 5      50         149  https://api.disneyapi.dev/characters?page=2
# 6      50         149  https://api.disneyapi.dev/characters?page=2
# 7      50         149  https://api.disneyapi.dev/characters?page=2
# 8      50         149  https://api.disneyapi.dev/characters?page=2
# 9      50         149  https://api.disneyapi.dev/characters?page=2
# 10     50         149  https://api.disneyapi.dev/characters?page=2
# 11     50         149  https://api.disneyapi.dev/characters?page=2
# ..    ...         ...                                          ...
# ...

# %%
# !pip install html-to-json

# %%
from pandas.io.json import json_normalize

result3= response3.json()
flattened_data = json_normalize(result3)

flattened_data
# Out:
# C:\Users\Yuga 14\AppData\Local\Temp\ipykernel_5344\1616606773.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(result3)
#                                                 data  count  totalPages  \
# 0  [{'films': [], 'shortFilms': [], 'tvShows': []...     50         149
#
#                                       nextPage
# 0  https://api.disneyapi.dev/characters?page=2

# %%
# Out:
# 0    [{'films': [], 'shortFilms': [], 'tvShows': []...
# Name: data, dtype: object
